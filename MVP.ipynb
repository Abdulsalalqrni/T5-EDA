# %%
#Libraries that we need
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
pd.set_option("display.float_format",lambda x: "%.5f" %x)

# %%
df=pd.read_csv("Tadawul_stcks.csv") #read csv file
df
# Out:
#         symbol                         name trading_name       sectoer  \
# 0         2030  Saudi Arabia Refineries Co.         SARCO       Energy
# 1         2030  Saudi Arabia Refineries Co.         SARCO       Energy
# 2         2030  Saudi Arabia Refineries Co.         SARCO       Energy
# 3         2030  Saudi Arabia Refineries Co.         SARCO       Energy
# 4         2030  Saudi Arabia Refineries Co.         SARCO       Energy
# ...        ...                          ...           ...          ...
# 593814    4321          Arabian Centres Co.      ALMRAKEZ  Real Estate
# 593815    4321          Arabian Centres Co.      ALMRAKEZ  Real Estate
# 593816    4321          Arabian Centres Co.      ALMRAKEZ  Real Estate
# 593817    4321          Arabian Centres Co.      ALMRAKEZ  Real Estate
# 593818    4321          Arabian Centres Co.      ALMRAKEZ  Real Estate
#
#               date     open     high      low    close   change  perc_Change  \
# ...

# %%
df.info()  # this for show the total information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593819 entries, 0 to 593818
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   symbol          593819 non-null  int64
#  1   name            593819 non-null  object
#  2   trading_name    593819 non-null  object
#  3   sectoer         593819 non-null  object
#  4   date            593819 non-null  object
#  5   open            587364 non-null  float64
#  6   high            587122 non-null  float64
#  7   low             587122 non-null  float64
#  8   close           593819 non-null  float64
#  9   change          593819 non-null  float64
#  10  perc_Change     593819 non-null  float64
#  11  volume_traded   593819 non-null  float64
#  12  value_traded    593819 non-null  float64
#  13  no_trades       586128 non-null  float64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 63.4+ MB

# %%
df.describe() #summary statistic
# Out:
#             symbol         open         high          low        close  \
# count 593819.00000 587364.00000 587122.00000 587122.00000 593819.00000
# mean    3952.68479     41.23779     41.97164     40.59341     40.96160
# std     2284.49853     86.71365     89.17818     84.56228     86.49171
# min     1010.00000      1.95000      1.95000      1.95000      0.00000
# 25%     2140.00000     16.20000     16.40000     16.00000     16.07000
# 50%     4004.00000     26.50000     26.90500     26.10000     26.30000
# 75%     5110.00000     46.50000     47.20000     45.85000     46.20000
# max     8312.00000   6709.15000   6774.51000   6130.72000   6441.18000
#
#             change  perc_Change  volume_traded       value_traded   no_trades
# count 593819.00000 593819.00000    593819.00000      593819.00000 586128.00000
# mean       0.00117      0.03565   1673421.73607    50085532.39852    960.64235
# std        4.78254      3.48078   5482121.37590   147296872.58997   3401.79414
# ...

# %%
df.head() # this for show the top five
# Out:
#    symbol                         name trading_name  sectoer        date  \
# 0    2030  Saudi Arabia Refineries Co.         SARCO  Energy  2020-03-05
# 1    2030  Saudi Arabia Refineries Co.         SARCO  Energy  2020-03-04
# 2    2030  Saudi Arabia Refineries Co.         SARCO  Energy  2020-03-03
# 3    2030  Saudi Arabia Refineries Co.         SARCO  Energy  2020-03-02
# 4    2030  Saudi Arabia Refineries Co.         SARCO  Energy  2020-03-01
#
#       open     high      low    close   change  perc_Change  volume_traded   \
# 0 35.55000 35.85000 34.90000 34.90000 -0.40000     -1.13000    436609.00000
# 1 34.70000 35.65000 34.50000 35.30000  0.25000      0.71000    737624.00000
# 2 34.70000 35.15000 34.70000 35.05000  1.05000      3.09000    489831.00000
# 3 35.20000 35.65000 34.00000 34.00000 -0.55000     -1.59000    736157.00000
# 4 35.35000 35.60000 34.25000 34.55000 -2.05000     -5.60000    738685.00000
#
#     value_traded  no_trades
# 0 15399073.50000   804.00000
# ...

# %%
df.tail() # this for show the top five
# Out:
#         symbol                 name trading_name       sectoer        date  \
# 593814    4321  Arabian Centres Co.      ALMRAKEZ  Real Estate  2019-05-28
# 593815    4321  Arabian Centres Co.      ALMRAKEZ  Real Estate  2019-05-27
# 593816    4321  Arabian Centres Co.      ALMRAKEZ  Real Estate  2019-05-26
# 593817    4321  Arabian Centres Co.      ALMRAKEZ  Real Estate  2019-05-23
# 593818    4321  Arabian Centres Co.      ALMRAKEZ  Real Estate  2019-05-22
#
#            open     high      low    close   change  perc_Change  \
# 593814 22.90000 22.90000 21.62000 22.50000  0.00000      0.00000
# 593815 23.30000 23.32000 22.24000 22.50000 -0.84000     -3.60000
# 593816 24.60000 24.60000 23.30000 23.34000 -1.16000     -4.73000
# 593817 24.80000 25.00000 24.34000 24.50000 -0.50000     -2.00000
# 593818 26.00000 26.10000 23.60000 25.00000 -1.00000     -3.85000
#
#         volume_traded     value_traded  no_trades
# 593814   1860532.00000  41495658.12000  2023.00000
# ...

# %%
df.drop(df[df.name==509.0].index,inplace=True)

# %%
df.drop(df[df.name==26.3].index,inplace=True)

# %%
df.drop(df[df.name==26.9].index,inplace=True)

# %%
df.drop(df[df.name==26.5].index,inplace=True)

# %%
df[df['open']>1000]=df["open"].median()

# %%
df[df['high']>1000]=df["high"].median()

# %%
df[df['close']>1000]=df["close"].median()

# %%
df[df['close']==0]=df["close"].median()

# %%
df[df['change']>100]=df["change"].median()

# %%
df[df['change']==0]=df["change"].median()

# %%
df[df["perc_Change"]>1000]=df["perc_Change"].median()

# %%
df[df['perc_Change']==0]=df["perc_Change"].median()

# %%
df[df["volume_traded "]>1000000000]=df["volume_traded "].median()

# %%
df[df['volume_traded ']==0]=df["volume_traded "].median()

# %%
df[df['value_traded']>1000000000]=df["value_traded"].median()

# %%
df[df['value_traded']==0]=df["value_traded"].median()

# %%
df[df["no_trades "]>1000]=df["no_trades "].median()

# %%
df[df["no_trades "]==0]=df["no_trades "].median()

# %%
df.drop(["symbol","trading_name "],axis=1,inplace=True)

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['day'] = df['date'].dt.day_name()

# %%
open_avg=df.open.median()
open_avg
# Out:
# 43.21

# %%
df.open.fillna(open_avg,inplace=True) # open column has NAN values so we have to handle it. I handle it using the median of the column

# %%
high_avg=df.high.median()
high_avg
# Out:
# 43.75

# %%
df.high.fillna(high_avg,inplace=True)

# %%
low_avg=df.low.median()
low_avg
# Out:
# 42.71

# %%
df.low.fillna(low_avg,inplace=True)

# %%
no_trades_avg=df["no_trades "].median()
no_trades_avg
# Out:
# 509.0

# %%
df["no_trades "].fillna(no_trades_avg,inplace=True)

# %% [markdown]
# # Q1) What the maximum opening in the Saudi Stock Market(Tadawul)?

# %%
df["open"].max()
# Out:
# 977.12

# %%
plt.figure(figsize =[40,25],dpi=250);
plt.plot(df["open"])
plt.title("The maximum opening in the Saudi Stock Market(Tadawul)",fontsize =40)
plt.ylabel("The opening price",fontsize =40)
plt.rc('xtick',labelsize=35) 
plt.rc('ytick',labelsize=35)
plt.savefig("photo.jpg")

# %% [markdown]
# # Q2) What is the lowest and highest performance day in the Saudi Stock Market(Tadawul)?

# %%
lowest_day=df.groupby("day")[["low"]].max()
lowest_day
# Out:
#                 low
# day
# Monday    686.27000
# Saturday  732.03000
# Sunday    964.05000
# Thursday  977.12000
# Tuesday   823.28000
# Wednesday 869.28000

# %%
highest_day=df.groupby("day")[["high"]].max()
highest_day
# Out:
#                high
# day
# Monday    702.61000
# Saturday  754.90000
# Sunday    964.05000
# Thursday  977.12000
# Tuesday   839.10000
# Wednesday 869.28000

# %%
plt.figure(figsize=[27,11],dpi=250)
plt.suptitle("The lowest and highest performance day in the Saudi Stock Market",fontsize =21)
plt.subplot(1,2,1)
plt.barh(lowest_day.index,lowest_day["low"],color="#2e8b57")
plt.title("The lowest performance day in the Saudi Stock Market",fontsize =19)
plt.xlabel("The lowest price of the stock at that day",fontsize =19);
plt.ylabel("The day of the stock price",fontsize =19);
plt.rc('xtick',labelsize=19) 
plt.rc('ytick',labelsize=19)
plt.subplot(1,2,2)
plt.barh(highest_day.index,highest_day["high"],color="#8b2e2e")
plt.title("The highest performance day in the Saudi Stock Market",fontsize =19);
plt.xlabel("The highest price of the stock at that day",fontsize =19);
plt.ylabel("The day of the stock price",fontsize =19);
plt.rc('xtick',labelsize=19) 
plt.rc('ytick',labelsize=19)
plt.savefig("image.jpg")

# %% [markdown]
# # Q3) What are the top five companies in the Saudi Stock Market(Tadawul)?

# %%
top_5_co=df.groupby("name")[["high"]].max().reset_index().sort_values("high",ascending=False).head()
top_5_co
# Out:
#                                             name      high
# 43             Anaam International Holding Group 977.12000
# 148                          Saudi Fisheries Co. 839.10000
# 183  Tihama Advertising and Public Relations Co. 803.00000
# 107                           Nama Chemicals Co. 475.50000
# 190      Wafrah for Industry and Development Co. 469.92000

# %%
plt.figure(figsize = [6,6])
sns.barplot(x=top_5_co["name"],y=top_5_co["high"])
plt.title(" Top five companies in the Saudi Stock Market",fontsize =15);
plt.xlabel("Name of the company",fontsize =15);
plt.ylabel("The highest price of the stock at that day",fontsize =15);
plt.rc('xtick',labelsize=12) 
plt.rc('ytick',labelsize=11)
plt.xticks(rotation=90)
plt.grid()
plt.savefig("figure.jpg")

# %% [markdown]
# # Q4)  What are the top ten companies which were the biggest exchanges?

# %%
top_5_co_=df.groupby("name")[["volume_traded "]].max().reset_index().sort_values("volume_traded ",ascending=False).head(10) 
top_5_co_
# Out:
#                                           name  volume_traded
# 33                                 Alinma Bank 113913049.00000
# 155                      Saudi Investment Bank  56326697.00000
# 57                                Bank Albilad  49725742.00000
# 124                                 Riyad Bank  39906064.00000
# 114             National Industrialization Co.  38540377.00000
# 51                    Arriyadh Development Co.  36196892.00000
# 58                               Bank Aljazira  34720989.00000
# 128     Sahara International Petrochemical Co.  31389476.00000
# 87                       Jadwa REIT Saudi Fund  30606121.00000
# 64   Bupa Arabia for Cooperative Insurance Co.  29056791.00000

# %%
plt.figure(figsize = [7,7])
plt.barh(top_5_co_["name"],top_5_co_["volume_traded "],color="#2e8b57")
plt.title("Top ten companies which were the biggest exchanges",fontsize =16)
plt.xticks(rotation = 90);
plt.xticks(rotation = 90);
plt.xlabel("Name of the company",fontsize =15);
plt.ylabel("The volume of the trades",fontsize =15);
plt.rc('xtick',labelsize=15) 
plt.rc('ytick',labelsize=15)
plt.grid()
plt.savefig("image_1.jpg")

# %% [markdown]
# # Q5) What is the most sectoer in the saudi stock market(TADAWAL)?

# %%
most_sectoer=df["sectoer"].value_counts()
most_sectoer.index
# Out:
# Index(['Financials', 'Materials', 'Industrials', 'Consumer Discretionary',
#        'Consumer Staples', 'Real Estate', 'Health Care',
#        'Communication Services', 'Energy', 'Utilities',
#        'Information Technology'],
#       dtype='object')

# %%
plt.figure(figsize = [7,7])
plt.title("Most sectoer in the saudi stock market(TADAWAL)",fontsize=13)
plt.xticks(rotation = 90);
plt.grid()
sns.countplot(data= df ,x = "sectoer" , order = most_sectoer.index)
plt.savefig("photo_1.jpg")
